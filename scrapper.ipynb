# %%
q=1
try:
    import requests
    from bs4 import BeautifulSoup
    from csv import writer
except Exception as e:
    print("Some modules are Missing {}".format(e))
#url = 'http://www.laughfactory.com/jokes/blonde-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/animal-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/clean-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/national-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/office-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/pop-culture-jokes/'+str(q)
url = 'https://www.rd.com/jokes/corny/'+str(q)
#url = 'http://www.laughfactory.com/jokes/political-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/miscellaneous-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/insult-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/how-to-be-insulting/'+str(q)
#url = 'http://www.laughfactory.com/jokes/holiday-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/food-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/family-jokes/'+str(q)
#url = 'http://www.laughfactory.com/jokes/boycott-these-jokes/'+str(q)
headers = {
'Accept-Encoding': 'gzip, deflate, sdch',
'Accept-Language': 'en-US,en;q=0.8',
'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Referer': 'http://www.wikipedia.org/',
'Connection': 'keep-alive',}


r =requests.get(url, headers)
##print(r.text)
data = []
final=[]

soup = BeautifulSoup(r.text, 'html.parser')
#print(soup)
div = soup.find('div',class_="jokes-sec")
for x in div.findAll('div', class_="joke-text"):
    data.append(x.text.strip())

for i ,x in enumerate(data):
    #print(i,x)
    final=[x]
    #print(final)
    #break

    with open('newevent.csv', 'a') as f_object:
        writer_object = writer(f_object)

    # Pass the list as an argument into
    # the writerow()
        writer_object.writerow(final)

    #Close the file object
        f_object.close()  

# print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-dc760e94d894> in <module>
#      38 #print(soup)
#      39 div = soup.find('div',class_="jokes-sec")
# ---> 40 for x in div.findAll('div', class_="joke-text"):
#      41     data.append(x.text.strip())
#      42
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
import pandas as pd
df = pd.read_csv("jokes_edited.csv", header=None)
#checking the number of empty rows in th csv file
print (df.isnull().sum())
#Droping the empty rows
modifiedDF = df.dropna()
#Saving it to the csv file 
modifiedDF.to_csv('jokes_edited.csv',index=False,)
# Out:
# 0    0
# dtype: int64

# %%
df.rename(columns = {0:'Jokes'}, inplace = True)

# %%
df
# Out:
#                                                   Jokes
# 1     Reporter: "Excuse me, may I interview you?" Ma...
# 2     What happens to a frog's car when it breaks do...
# 3     Q: What did the duck say when he bought lipsti...
# 4     A blonde and a redhead have a ranch. They have...
# 5     A boy is selling fish on a corner. To get his ...
# ...                                                 ...
# 2893  Yo momma's so stupid, she thought Chicken Pot ...
# 2894  Yo momma's so ugly, they push her face into th...
# 2895  Yo momma's so stupid, she cooks Indian curry w...
# 2896  Yo momma's so stupid, she watches "The Three S...
# 2897  Yo momma's so stupid, she asked me what jeans ...
#
# [2897 rows x 1 columns]

# %%
df.to_csv('jokes_edited.csv',index=False,)

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                   Jokes
# 1     Reporter: "Excuse me, may I interview you?" Ma...
# 2     What happens to a frog's car when it breaks do...
# 3     Q: What did the duck say when he bought lipsti...
# 4     A blonde and a redhead have a ranch. They have...
# 5     A boy is selling fish on a corner. To get his ...
# ...                                                 ...
# 2893  Yo momma's so stupid, she thought Chicken Pot ...
# 2894  Yo momma's so ugly, they push her face into th...
# 2895  Yo momma's so stupid, she cooks Indian curry w...
# 2896  Yo momma's so stupid, she watches "The Three S...
# 2897  Yo momma's so stupid, she asked me what jeans ...
#
# [2897 rows x 1 columns]>

# %%
df['Jokes'][65]
# Out:
# 'A man walk into a bar and says, "Give me something to drink just no vodka." The bartender asks, "Why? That\'s your typical drink of choice." The man replies, "Because last night I got drunk and blew Chunks." The bartender says, "Well, it\'s normal to blow chunks if you drink too much. The man says, "No, Chunks is my dog."'

# %%
231657
# Out:
# 231657

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
files = os.path.join("./", "data*.csv")

# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
print(df)
# Out:
# Resultant CSV after joining all CSV files at a particular location...
#             ID                                               Joke
# 0            1  [me narrating a documentary about narrators] "...
# 1            2  Telling my daughter garlic is good for you. Go...
# 2            3  I've been going through a really rough period ...
# 3            4  If I could have dinner with anyone, dead or al...
# 4            5     Two guys walk into a bar. The third guy ducks.
# ...        ...                                                ...
# 234549  234549  Yo momma's so stupid, she thought Chicken Pot ...
# 234550  234550  Yo momma's so ugly, they push her face into th...
# 234551  234551  Yo momma's so stupid, she cooks Indian curry w...
# 234552  234552  Yo momma's so stupid, she watches "The Three S...
# 234553  234553  Yo momma's so stupid, she asked me what jeans ...
#
# [234554 rows x 2 columns]

# %%
df.to_csv('jokes_edited.csv',index=False,)

# %%
def joker():
         import pyjokes
         print(pyjokes.get_joke(language='en', category='all'))

# %%
joker()
# Out:
# Chuck Norris never has to build his program to machine code. Machines have learnt to interpret Chuck Norris's code.

# %%
for i in range(300):
    print(pyjokes.get_joke(language='en', category='all'))
# Out:
# Chuck Norris can retrieve anything from /dev/null.
# The only design pattern Chuck Norris knows is the God Object Pattern.
# I would tell you a joke about UDP, but you would never get it.
# What do you get when you cross a cat and a dog? Cat dog sin theta.
# What do you get when you cross a cat and a dog? Cat dog sin theta.
# Chuck Norris doesn't need a debugger, he just stares at the code until it confesses.
# !false, (It's funny because it's true)
# If you try to kill -9 Chuck Norris's programs, it backfires.
# Chuck Norris performs infinite loops in under 4 seconds.
# Chuck Norris's database has only one table, 'Kick', which he drops frequently.
# How do you generate a random string? Put a first year Computer Science student in Vim and ask them to save and exit.
# Why did the QA cross the road? To ruin everyone's day.
# Every SQL statement that Chuck Norris codes has an implicit 'COMMIT' in its end.
# Why did Microsoft name their search engine BING? Because It's Not Google.
# ...

# %%
print(pyjokes.get_joke(language='en', category='all'))
# Out:
# The Chuck Norris protocol design method has no status, requests or responses, only commands.
